// %% [markdown]
// https://kotlinlang.org/docs/kotlin-tips.html

// %% [markdown]
// https://developer.android.com/training/testing/fundamentals/strategies

// %% [markdown]
// https://www.simplifiedcoding.net/android-interview-questions/

// %% [markdown]
// https://play.kotlinlang.org/koans/Introduction

// %% [markdown]
// https://developer.android.com/courses/unit/kotlin-basics-unit-1?utm_source=chatgpt.com

// %% [markdown]
// https://developer.android.com/courses/android-development-with-kotlin/unit-1?utm_source=chatgpt.com

// %% [markdown]
// https://exercism.org/tracks/kotlin/exercises/hello-world/edit

// %% [markdown]
// https://developer.android.com/codelabs/basic-android-kotlin-compose-kotlin-fundamentals-practice-problems?utm_source=chatgpt.com#0

// %% [markdown]
// https://www.codewars.com/kata/search/kotlin?utm_source=chatgpt.com

// %% [markdown]
// https://play.kotlinlang.org/koans/overview

// %% [markdown]
// https://www.testgorilla.com/blog/kotlin-interview-questions/?utm_term=&utm_campaign=PMax_T3_Intl&utm_source=google&utm_medium=cpc&hsa_acc=4932434860&hsa_cam=23769984904&hsa_grp=&hsa_ad=&hsa_src=x&hsa_tgt=&hsa_kw=&hsa_mt=&hsa_net=adwords&hsa_ver=3&gad_source=1&gad_campaignid=23770030258&gbraid=0AAAAABnxgtCQYD34m-XFiJMAimXXyAQDe&gclid=Cj0KCQjwz9_QBhD_ARIsADnSCfDJ_Y14-CTmsW1xnir1JO1OM3XUQT92SrynJe5EmAxG-CgtXc8UfAIaAsigEALw_wcB

// %% [markdown]
// https://coderpad.io/interview-questions/kotlin-interview-questions/

// %% [markdown]
// https://blog.mindorks.com/kotlin-android-interview-questions/

// %% [markdown]
// https://proandroiddev.com/android-interview-series-2024-part-1-android-basics-23a713f4a648
