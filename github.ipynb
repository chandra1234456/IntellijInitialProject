// %%
// Out:
// org.jetbrains.kotlinx.jupyter.exceptions.ReplCompilerException: at Cell In[1], line 1, column 1: Expecting an element
// at Cell In[1], line 1, column 7: Expecting an element
// at Cell In[1], line 3, column 1: Expecting an element
// at Cell In[1], line 3, column 2: Expecting an element
// at Cell In[1], line 3, column 4: Expecting an element
// at Cell In[1], line 5, column 1: Expecting an element
// at Cell In[1], line 5, column 2: Expecting an element
// at Cell In[1], line 5, column 3: Expecting an element
// at Cell In[1], line 6, column 10: Expecting an element
// at Cell In[1], line 6, column 11: Expecting an element
// at Cell In[1], line 6, column 46: Expecting an element
// at Cell In[1], line 6, column 71: Expecting an element
// at Cell In[1], line 6, column 114: Expecting an element
// at Cell In[1], line 8, column 4: Expecting an element
// at Cell In[1], line 10, column 1: Expecting an element
// at Cell In[1], line 10, column 2: Expecting an element
// ...

// %% [markdown]
// # Git & GitHub Interview Questions
//
// ## 📌 Basic Git Questions
//
// ### 1. What is Git?
// Git is a **distributed version control system** used to track changes in source code and collaborate with others.
//
// ---
//
// ### 2. What is Version Control?
// Version control helps manage changes to files over time, allowing you to:
// - Track history
// - Revert changes
// - Collaborate safely
//
// ---
//
// ### 3. Difference between Git and GitHub?
// | Git | GitHub |
// |---|---|
// | Version control tool | Hosting platform |
// | Works locally | Works online |
// | Tracks code changes | Stores & shares Git repositories |
//
// ---
//
// ### 4. What is a repository?
// A repository (repo) is a place where project files and their version history are stored.
//
// ---
//
// ### 5. What is `git init`?
// Initializes a new Git repository.
// ```bash
// git init

// %% [markdown]
// ┌─────────────────────────────────────────────┐
// │         ESSENTIAL GIT COMMANDS              │
// ├─────────────────────────────────────────────┤
// │                                             │
// │  Setup:                                    │
// │  git init          # Initialize repo        │
// │  git clone <url>   # Clone repo            │
// │                                            │
// │  Basic:                                    │
// │  git add <file>    # Stage changes         │
// │  git commit -m ""  # Commit changes        │
// │  git status        # Check status          │
// │  git log           # View history          │
// │                                            │
// │  Branching:                                │
// │  git branch        # List branches         │
// │  git checkout -b   # Create & switch       │
// │  git merge         # Merge branches        │
// │  git rebase        # Reapply commits       │
// │                                            │
// │  Remote:                                   │
// │  git push          # Push to remote        │
// │  git pull          # Fetch + merge         │
// │  git fetch         # Fetch only            │
// │                                            │
// │  Undo:                                     │
// │  git reset         # Undo commit           │
// │  git revert        # Safe undo             │
// │  git stash         # Save temporarily      │
// └─────────────────────────────────────────────┘
