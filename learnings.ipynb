// %% [markdown]
// # 🚀 Kotlin Practice Problems (100 Challenges)
//
// A progressive list of **100 Kotlin problems** — from beginner basics to advanced problem solving.
//
// ---
//
// ## 🧠 Beginner (1–20)
//
// 1. Print “Hello, World!”
// 2. Swap two variables without a third
// 3. Check if number is even/odd
// 4. Find the maximum of 3 numbers
// 5. Calculate factorial of a number
// 6. Print first 10 Fibonacci numbers
// 7. Reverse a string
// 8. Calculate sum of digits of a number
// 9. Check if string is palindrome
// 10. Print multiplication table of a number
// 11. Convert Celsius to Fahrenheit
// 12. Count vowels in a string
// 13. Sum all elements of an array
// 14. Find min and max in an array
// 15. Check if list contains duplicate values
// 16. Join a List to a String with commas
// 17. Compute average of list of numbers
// 18. Remove duplicates using a Set
// 19. Print characters of string one per line
// 20. Count number of words in a sentence
//
// ---
//
// ## 📚 Control Flow (21–40)
//
// 21. Check if year is leap year
// 22. Print even numbers from 1–50
// 23. Sum of all even numbers in a range
// 24. Print pattern (triangle) with stars
// 25. Find the length of string without `.length`
// 26. Check prime number
// 27. Print prime numbers up to N
// 28. Check if number is power of 2
// 29. FizzBuzz up to 50
// 30. Nested loop pattern: Floyd’s triangle
// 31. Largest prime factor of a number
// 32. Sum of squares from 1–N
// 33. Convert number to binary string
// 34. Print list in reverse without reversing
// 35. Print alternating odd–even from 1–n
// 36. Find index of first negative in array
// 37. Check if array is sorted
// 38. Count negative numbers in list
// 39. Print Pascal’s triangle
// 40. Find GCD of two numbers
//
// ---
//
// ## 🌀 Functions & Recursion (41–60)
//
// 41. Write recursive factorial
// 42. Write recursive Fibonacci
// 43. Sum of digits (recursively)
// 44. Power(x, n) using recursion
// 45. Reverse string using recursion
// 46. Check palindrome using recursion
// 47. Count occurrences of char in string
// 48. Function to swap two numbers
// 49. Function returning list of primes up to N
// 50. Function to check Armstrong number
// 51. Function with `vararg` params
// 52. Extension function for List<Int> to get sum
// 53. Function to convert list to set
// 54. Function to get common items in two lists
// 55. Function to flatten List<List<Int>>
// 56. Calculate factorial tail recursively
// 57. Function to repeat action N times
// 58. Function to find second max
// 59. Function to remove element at index
// 60. Lambda to multiply two numbers
//
// > Related exercises on w3resource include these and more in the function and recursion categories. :contentReference[oaicite:1]{index=1}
//
// ---
//
// ## 🔍 Collections & Lambdas (61–80)
//
// 61. `map` to square list entries
// 62. `filter` for even numbers
// 63. `reduce` to compute product
// 64. Count frequency of words in a list
// 65. Sort list of strings by length
// 66. Group list elements by first letter
// 67. Flatten nested lists
// 68. Convert List<String> to List<Int>
// 69. Filter `null` values safely with `?.let`
// 70. Create `Map<Char, Int>` frequency from string
// 71. Print keys and values of map
// 72. `mapNotNull` examples
// 73. Chain `filter` + `map`
// 74. Unique sorted list
// 75. Find all pairs with sum = target
// 76. Partition list into even/odd
// 77. Functional pipeline: double and sum
// 78. Transform list to uppercase strings
// 79. Create map from list grouping by length
// 80. Remove items based on predicate
//
// ---
//
// ## 📈 Algorithms & Challenges (81–100)
//
// 81. Linear search implementation
// 82. Binary search on sorted list
// 83. Bubble sort
// 84. Selection sort
// 85. Insertion sort
// 86. Quick sort (recursive)
// 87. Merge sort (divide & conquer)
// 88. List all subarrays
// 89. Max sum subarray (Kadane’s)
// 90. Longest increasing sub-sequence
// 91. Anagram checker
// 92. Caesar cipher encryption
// 93. Check array rotation equality
// 94. Matrix transpose
// 95. Spiral traversal
// 96. Count islands in 2D matrix
// 97. Word ladder basics
// 98. Balanced parentheses checker
// 99. Simple calculator parser
// 100. Build a small contact list CLI app
//
// ---
//
// ## 📌 Notes & Resources
//
// - Try exercises from **Exercism (88 Kotlin tasks)** — great for structured practice. :contentReference[oaicite:2]{index=2}
// - GitHub coding challenge repository *kotlin-coding-challenges* has many puzzles with tests. :contentReference[oaicite:3]{index=3}
// - Beginner/intermediate tasks with solutions at w3resource. :contentReference[oaicite:4]{index=4}
// - For *syntax-focused learning*, consider **Kotlin Koans**, a guided exercise suite. :contentReference[oaicite:5]{index=5}
//
// ---
//
// Happy coding! 🎯
