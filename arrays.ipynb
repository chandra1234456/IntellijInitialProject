// %% [markdown]
// 🔹 Basic Array Interview Questions
//
// 1.What is an array?
//
// Difference between array and ArrayList?
//
// What is the index of the first element in an array?
//
// Can arrays store different data types?
//
// What is the size of an array and how is it fixed?
//
// How do you declare and initialize an array?
//
// What happens if you access an index out of bounds?
//
// How to find the length of an array?

// %% [markdown]
// 🔹 Intermediate Array Questions
//
// How do you reverse an array?
//
// How do you find the largest and smallest elements in an array?
//
// How do you find duplicate elements in an array?
//
// How do you sort an array?
//
// How do you merge two arrays?
//
// Difference between 1D and 2D arrays?
//
// How do you copy one array into another?
//
// What is a sparse array?

// %% [markdown]
// 🔹 Problem-Solving / Coding Questions
//
// Find the second largest element in an array
//
// Find missing number in an array (1 to N)
//
// Move all zeros to the end of the array
//
// Find the frequency of elements in an array
//
// Rotate an array by K positions
//
// Check if array is sorted
//
// Find common elements between two arrays
//
// Remove duplicate elements from an array

// %% [markdown]
// 🔹 Advanced Array Interview Questions
//
// What is the time complexity of array operations?
//
// Why is array access faster than LinkedList?
//
// Difference between static and dynamic arrays?
//
// Explain jagged arrays
//
// How memory is allocated to arrays?
//
// What is sliding window technique?
//
// Kadane’s Algorithm (Maximum Subarray Sum)
//
// Two Sum problem
//
// Trapping Rain Water problem

// %% [markdown]
// 🔹 Android / Kotlin Specific
//
// Difference between Array, IntArray, and ArrayList in Kotlin?
//
// How do you iterate over an array in Kotlin?
//
// What is indices and withIndex()?
//
// How to convert array to list and list to array?
//
// What happens when array size is exceeded in Kotlin?

// %% [markdown]
// 🔹 Most Frequently Asked (⭐ Focus Here)
//
// ⭐ Reverse an array
// ⭐ Second-largest element
// ⭐ Remove duplicates
// ⭐ Rotate array
// ⭐ Two Sum problem

// %%
// Out:
// org.jetbrains.kotlinx.jupyter.exceptions.ReplCompilerException: at Cell In[1], line 1, column 6: Expecting an element
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.JupyterCompilerImpl.compileSync(JupyterCompilerImpl.kt:151)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.InternalEvaluatorImpl.eval(InternalEvaluatorImpl.kt:126)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.CellExecutorImpl.execute_L4Nmkdk$lambda$0$0(CellExecutorImpl.kt:80)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl.withHost(ReplForJupyterImpl.kt:791)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.CellExecutorImpl.execute-L4Nmkdk(CellExecutorImpl.kt:78)
// 	at org.jetbrains.kotlinx.jupyter.repl.execution.CellExecutor.execute-L4Nmkdk$default(CellExecutor.kt:14)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl.evaluateUserCode-wNURfNM(ReplForJupyterImpl.kt:616)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl.evalExImpl(ReplForJupyterImpl.kt:474)
// ...
