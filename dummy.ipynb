// %%
val add = 4+3

add
// Out:
// 7

// %% [markdown]
// # Kotlin Notebook: Charts Example
// This notebook demonstrates:
// - Basic Kotlin operations
// - Using DataFrames
// - Creating charts with Kandy

// %%
// Basic Kotlin variables and operations
val numbers = listOf(10, 20, 30, 40, 50)
val average = numbers.average()
val max = numbers.maxOrNull()
val min = numbers.minOrNull()

println("Numbers: $numbers")
println("Average: $average, Max: $max, Min: $min")
// Load libraries for charts and data
%use dataframe
%use kandy
// Out:
// Numbers: [10, 20, 30, 40, 50]
// Average: 30.0, Max: 50, Min: 10

// %%
%use dataframe
%use kandy

// %%
val faceFrequency = rolls.
