// %% [markdown]
// # 📱 Android + IntelliJ IDEA Learning Resources (Markdown)
//
// This file contains **curated Android & IntelliJ IDEA learning links**, mainly focused on **Kotlin, Android development, and productivity with IntelliJ / Android Studio**.
//
// ---
//
// ## 🚀 Android Development – Official Resources
//
// * 🔗 [Android Developers – Official Site](https://developer.android.com)
// * 🔗 [Android Developers YouTube Channel](https://www.youtube.com/@AndroidDevelopers)
// * 🔗 [Android Kotlin Guide](https://developer.android.com/kotlin)
// * 🔗 [Jetpack Libraries Overview](https://developer.android.com/jetpack)
//
// ---
//
// ## ▶️ Android Development – YouTube Playlists
//
// ### ⭐ Beginner to Intermediate
//
// * 🔗 [Android Development for Beginners – freeCodeCamp](https://www.youtube.com/watch?v=fis26HvvDII)
// * 🔗 [Android Kotlin Tutorials – Philipp Lackner](https://www.youtube.com/@PhilippLackner)
// * 🔗 [Android Tutorials – Coding in Flow](https://www.youtube.com/@codinginflow)
// * 🔗 [Android + Kotlin – Stevdza-San](https://www.youtube.com/@StevdzaSan)
//
// ---
//
// ## 🧩 Jetpack Compose (Modern Android UI)
//
// * 🔗 [Jetpack Compose Official Pathway](https://developer.android.com/courses/pathways/compose)
// * 🔗 [Jetpack Compose Tutorials – Android Developers](https://www.youtube.com/playlist?list=PLWz5rJ2EKKc9CBxr3BVjPTPoDPLdPIFCE)
// * 🔗 [Jetpack Compose – Philipp Lackner](https://www.youtube.com/playlist?list=PLQkwcJG4YTCQ6emtoqSZS2FVwZR9FT3BV)
//
// ---
//
// ## 💡 IntelliJ IDEA – Official Resources
//
// ### ▶️ IntelliJ IDEA (JetBrains)
//
// * 🔗 [IntelliJ IDEA Official YouTube](https://www.youtube.com/@IntelliJIDEA)
// * 🔗 [IntelliJ IDEA Tutorials Playlist](https://www.youtube.com/playlist?list=PLQ176FUIyIUY6gF4W2k1J4vN6tF8n2K0_)
//
// ### 📘 IntelliJ Documentation
//
// * 🔗 [IntelliJ IDEA Documentation](https://www.jetbrains.com/idea/documentation/)
// * 🔗 [IntelliJ Keyboard Shortcuts](https://www.jetbrains.com/help/idea/mastering-keyboard-shortcuts.html)
// * 🔗 [Debugging in IntelliJ IDEA](https://www.jetbrains.com/help/idea/debugging-code.html)
//
// ---
//
// ## 🧑‍💻 Kotlin + IntelliJ (Together)
//
// * 🔗 [Kotlin Official Website](https://kotlinlang.org)
// * 🔗 [Kotlin YouTube Channel (JetBrains)](https://www.youtube.com/@Kotlin)
// * 🔗 [Kotlin in IntelliJ IDEA – Video](https://www.youtube.com/watch?v=4k4pMTsa1Kw)
// * 🔗 [Productivity Tips for Kotlin in IntelliJ](https://www.youtube.com/watch?v=K8O8K6vJYyA)
//
// ---
//
// ## ⚡ Android Studio (Built on IntelliJ)
//
// > Android Studio is based on IntelliJ IDEA
//
// * 🔗 [Android Studio Documentation](https://developer.android.com/studio)
// * 🔗 [Android Studio Tips & Tricks](https://developer.android.com/studio/intro/keyboard-shortcuts)
// * 🔗 [Android Studio YouTube Tips](https://www.youtube.com/playlist?list=PLWz5rJ2EKKc9CBxr3BVjPTPoDPLdPIFCE)
//
// ---
//
// ## 🧪 Practice & Hands-on
//
// * 🔗 [Kotlin Playground](https://play.kotlinlang.org)
// * 🔗 [Android Codelabs](https://developer.android.com/codelabs)
// * 🔗 [GitHub Android Samples](https://github.com/android)
//
// ---
//
// ## 🗺️ Suggested Learning Order
//
// 1. Kotlin Basics (IntelliJ)
// 2. OOP + Collections
// 3. Android Fundamentals
// 4. MVVM + Architecture
// 5. Jetpack Compose
// 6. Debugging & Refactoring in IntelliJ
// 7. Performance & Best Practices
//
// ---
//
// ## ✅ Tip
//
// 📌 Save this file as `Android_IntelliJ_Learning_Resources.md`
//
// If you want next, I can:
//
// * Create a **30‑day Android + Kotlin roadmap**
// * Add **interview‑focused Android links**
// * Add **Compose‑only advanced resources**
// * Convert this into **PDF**
