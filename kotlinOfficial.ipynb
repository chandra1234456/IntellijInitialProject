// %% [markdown]
// # 📘 Kotlin Learning Resources (YouTube & Official Links)
//
// This Markdown file contains **high-quality Kotlin learning resources**, especially useful for **Android developers**, beginners, and interview preparation.
//
// ---
//
// ## 🎯 Official Kotlin Resources (Must Follow)
//
// * 🔗 [Kotlin Official Website](https://kotlinlang.org)
// * 🔗 [Kotlin Documentation](https://kotlinlang.org/docs/home.html)
// * 🔗 [Kotlin Playground (Practice Online)](https://play.kotlinlang.org)
// * 🔗 [Kotlin GitHub Repository](https://github.com/JetBrains/kotlin)
//
// ---
//
// ## ▶️ Best YouTube Channels for Kotlin
//
// ### ⭐ Beginner Friendly
//
// * 🔗 [Kotlin by JetBrains (Official)](https://www.youtube.com/@Kotlin)
// * 🔗 [CodeWithHarry – Kotlin Tutorial](https://www.youtube.com/watch?v=mnkzx3TwbV8)
// * 🔗 [freeCodeCamp Kotlin Course](https://www.youtube.com/watch?v=F9UC9DY-vIU)
//
// ---
//
// ### ⭐ Android + Kotlin (Highly Recommended)
//
// * 🔗 [Android Developers (Official)](https://www.youtube.com/@AndroidDevelopers)
// * 🔗 [Philipp Lackner](https://www.youtube.com/@PhilippLackner)
// * 🔗 [Coding in Flow](https://www.youtube.com/@codinginflow)
// * 🔗 [Stevdza-San](https://www.youtube.com/@StevdzaSan)
// * 🔗 [Aris Aghajanyan – Android & Compose](https://www.youtube.com/@ArisAghajanyan)
//
// ---
//
// ### ⭐ Kotlin Internals / Advanced
//
// * 🔗 [KotlinConf Talks](https://www.youtube.com/@KotlinConf)
// * 🔗 [Jake Wharton](https://www.youtube.com/@JakeWharton)
// * 🔗 [Roman Elizarov (Coroutines Expert)](https://www.youtube.com/@RomanElizarov)
//
// ---
//
// ## 🧠 Kotlin Language Concepts
//
// * 🔗 [Kotlin OOP Concepts](https://kotlinlang.org/docs/object-oriented-programming.html)
// * 🔗 [Kotlin Functional Programming](https://kotlinlang.org/docs/lambdas.html)
// * 🔗 [Kotlin Coroutines Guide](https://kotlinlang.org/docs/coroutines-overview.html)
// * 🔗 [Kotlin Flow](https://kotlinlang.org/docs/flow.html)
//
// ---
//
// ## 🧪 Practice & Coding Platforms
//
// * 🔗 [Kotlin Koans (Official Exercises)](https://kotlinlang.org/docs/koans.html)
// * 🔗 [HackerRank – Kotlin](https://www.hackerrank.com/domains/tutorials/10-days-of-kotlin)
// * 🔗 [LeetCode Kotlin Problems](https://leetcode.com/problemset/?language=Kotlin)
// * 🔗 [Codeforces (Kotlin)](https://codeforces.com)
//
// ---
//
// ## 📚 Android + Kotlin Special
//
// * 🔗 [Android Kotlin Style Guide](https://developer.android.com/kotlin/style-guide)
// * 🔗 [Jetpack Compose Basics](https://developer.android.com/jetpack/compose)
// * 🔗 [Compose Pathway (Official)](https://developer.android.com/courses/pathways/compose)
// * 🔗 [Android Architecture Guide](https://developer.android.com/topic/architecture)
//
// ---
//
// ## 🎤 Interview & Advanced Preparation
//
// * 🔗 [Kotlin Interview Questions – Baeldung](https://www.baeldung.com/kotlin)
// * 🔗 [Android Interview Questions](https://github.com/MindorksOpenSource/android-interview-questions)
// * 🔗 [Kotlin Design Patterns](https://refactoring.guru/design-patterns/kotlin)
//
// ---
//
// ## 🗺️ Suggested Learning Path
//
// 1. Kotlin Basics (syntax, val/var, functions)
// 2. OOP in Kotlin
// 3. Collections & Lambdas
// 4. Coroutines & Flow
// 5. Android with Kotlin
// 6. Jetpack Compose
// 7. Clean Architecture & MVVM
// 8. Interview Preparation
//
// ---
//
// ## ✅ Tip
//
// 📌 Bookmark this file as `Kotlin_Learning_Resources.md`
//
// If you want, I can:
//
// * Convert this to **PDF**
// * Create a **30-day Kotlin roadmap**
// * Add **Jetpack Compose-only resources**
// * Create **Beginner → Advanced checklist**
