// %% [markdown]
// https://github.com/amitshekhariitbhu/android-interview-questions

// %% [markdown]
// https://medium.com/@anandgaur2207/android-interview-questions-for-mid-level-developers-3-6-years-d915266ef936

// %% [markdown]
// https://proandroiddev.com/android-interview-series-2024-part-1-android-basics-23a713f4a648

// %% [markdown]
// https://medium.com/@anandgaur2207/dagger-hilt-in-android-ffcc08a343f3

// %% [markdown]
// https://www.ideamotive.co/android/interview

// %% [markdown]
// https://medium.com/@anandgaur2207/android-interview-questions-answer-part-i-ac26dfe4f8e6

// %% [markdown]
// https://www.interviewbit.com/android-interview-questions/

// %% [markdown]
// https://www.toptal.com/developers/android/interview-questions

// %% [markdown]
// https://github.com/mohsenoid/Android-Interview-Questions

// %% [markdown]
// https://javatechonline.com/pdf/
